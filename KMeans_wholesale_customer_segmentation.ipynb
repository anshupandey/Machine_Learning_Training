# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/Machine_Learning_Training/blob/master/KMeans_wholesale_customer_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import all the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset and store it into variable df
path = "https://raw.githubusercontent.com/anshupandey/Machine_Learning_Training/master/datasets/Wholesale%20customers%20data.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
df.shape
# Out:
# (440, 8)

# %%
# check for missing values
df.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
# check for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (440, 8)

# %% [markdown]
# ## Performing clustering on 2 featues

# %%
# Take 2 features Fresh and Milk out of df and create a new dataframe df2
df2 = df[["Fresh","Milk"]]

# %%
# Now we will perform clustering on df2
# importign the KMeans clustering class and creating the object
from sklearn.cluster import KMeans
model=KMeans(n_clusters=3,verbose=True,random_state=5) # mentioning the number of clusters as 3

# %%
# training the model
model.fit(df2)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 45758048504.54789
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 42407197420.16337
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 40564683904.46749
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 39870618687.08736
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 39244390531.85025
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 38541601749.73459
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 38329663769.775764
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 38184240984.984665
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 37971970826.29146
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 37789763411.8134
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 37729012858.995544
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 37709680295.28183
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 37698200700.71028
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 37698200700.71028
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 39546438927.003456
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 38079551019.466
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 37733421751.36456
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 37698200700.71028
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 37698200700.71028
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 46088405871.51455
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 41097033261.30142
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 39841046004.6449
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 39663052092.65224
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 39615359873.13103
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 39598406227.39682
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 39598406227.39682
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 44166387719.29869
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 42918550264.283966
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 42493701168.62671
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 42451751892.35712
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 42451751892.35712
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 39106456122.047905
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 38094633708.28915
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 38048961420.02876
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 38033425731.27937
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 38029895164.991844
# center shift 9.546647e+01 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 47059941277.8312
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 42854116342.65584
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 42374872850.45332
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 42269833363.70881
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 42269833363.70881
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 48165603332.44369
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 45990154160.94327
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 43914434926.13422
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 42776823200.04882
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 42492637493.69584
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 42455509049.36124
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 42429920604.973076
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 42420001188.38838
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 42420001188.38838
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 41227810869.11482
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 38544858909.70311
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 38006062605.436295
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 37713937408.9337
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 37698200700.71028
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 37698200700.71028
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 39159503793.92227
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 38303271142.8013
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 38115439716.52956
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 38057239224.06889
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 38045878101.82347
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 38026476489.92133
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 38026476489.92133
# center shift 0.000000e+00 within tolerance 1.069688e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 44320913394.02171
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 43142691411.471725
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 42827497613.58731
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 42650141103.96995
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 42557878665.26861
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 42540679734.03991
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 42531201310.68546
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 42486684780.45463
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 42465959484.39788
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 42465959484.39788
# center shift 0.000000e+00 within tolerance 1.069688e+04
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=5, tol=0.0001, verbose=True)

# %%
# analysing the patterns
model.cluster_centers_
# Out:
# array([[ 4992.68817204,  6019.75268817],
#        [44622.5625    , 12838.09375   ],
#        [19063.94573643,  3566.10077519]])

# %%
df2['cluster']=model.predict(df2)
df2.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Fresh   Milk  cluster
# 0  12669   9656        0
# 1   7057   9810        0
# 2   6353   8808        0
# 3  13265   1196        2
# 4  22615   5410        2
# 5   9413   8259        0
# 6  12126   3199        2
# 7   7579   4956        0
# 8   5963   3648        0
# 9   6006  11093        0

# %%
#analysing the cluster size
# use seaborn to draw the countplot of the cluster column in the dataframe df2
plt.figure(figsize=(8,6))
sns.countplot(model.labels_)
plt.show()

# %%
# Analysing the clusters using scatter plot
plt.figure(figsize=(12,5))
plt.scatter(x='Fresh',y='Milk',c='r',
            data=df2[df2['cluster']==0],
            label='Low Fresh, Medium Milk')
plt.scatter(x='Fresh',y='Milk',c='b',
            data=df2[df2['cluster']==1],
            label='High Fresh, High Milk')
plt.scatter(x='Fresh',y='Milk',c='g',
            data=df2[df2['cluster']==2],
            label='Modium Fresh, Low Milk')
plt.legend()
plt.show()

# %% [markdown]
# ## Performing Clustering for 4 features

# %%
# create a new dataframe df3 with 4 features of your choice
df3=df[["Fresh","Milk","Grocery","Frozen"]]

# %%
# create a clustering object
model2=KMeans(n_clusters=3,verbose=True,random_state=5)

# %%
#train the model - write code
model.fit(df3)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 84172524195.44225
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 76623078218.92621
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 73968491328.42773
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 73272790098.15724
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 73069215931.63672
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 72802727193.58038
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72562255859.23804
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72415606429.1792
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72347933135.09076
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72342231964.37271
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 72342231964.37271
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 80789626813.77399
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 75189730469.16609
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 73727719032.66684
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 73204615371.74991
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 72994238213.3899
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 72806430736.89233
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72566555108.32875
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72421435170.05658
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72347933135.09076
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72342231964.37271
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 72342231964.37271
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 79449021641.56917
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 74079240825.98216
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 73314781639.75284
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 73069215931.63672
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 72802727193.58038
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 72562255859.23804
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72415606429.1792
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72347933135.09076
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72342231964.37271
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72342231964.37271
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 102433020063.69704
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 95426109857.64484
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 92905539776.77492
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 92198699886.12558
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 91632186293.80707
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 91232649365.67941
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 90885060995.73563
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 90735645443.48856
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 90581169635.14621
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 90460873159.74106
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 90400187060.468
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 90290773966.33331
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 90142954080.93115
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 90068179932.22461
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 89802509751.10442
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 88845328280.22383
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 87036842207.9459
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 84480740341.30504
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 81216175459.04112
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 79210036928.31078
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 77935918398.95053
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 77517978502.88792
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 77061612644.45836
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 75448900825.2612
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 74873383064.884
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 74114033927.37106
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 73451136652.86234
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 73215426211.86963
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 73111601194.27559
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 73093685709.6383
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 73088205536.83505
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 73079984048.4876
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 73070497744.01451
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 73070497744.01451
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 86878493239.57959
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 81450184894.06981
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 76585527056.90295
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 73953963907.69409
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 73041998154.94348
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 72573516541.7804
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72327775437.9867
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72207270307.49844
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72172703724.19286
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72148350846.68796
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 72124021587.97287
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 72124021587.97287
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 79720388688.81097
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 74434679004.69142
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 73502151663.40543
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 73252941066.96152
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 73029982695.78903
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 72729924224.24121
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72442066098.79027
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72355560206.69585
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72350371430.00665
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72350371430.00665
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 81669413931.69682
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 78503114910.20863
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 76646220630.8322
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 75550926558.00728
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 74158542832.4566
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 73102791875.07265
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72586590712.19452
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72327775437.9867
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72207270307.49844
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72172703724.19286
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 72148350846.68796
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 72124021587.97287
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 72124021587.97287
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 89734356923.17242
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 88214310935.56264
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 87495809409.4073
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 86115434118.35147
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 85111952518.47096
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 83989361007.72478
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 79816916240.21747
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 77810897132.11543
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 76449310687.27386
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 75324300231.25009
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 73994981685.00581
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 72985701197.89218
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 72476826007.9945
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 72300451342.4786
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 72207270307.49844
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 72172703724.19286
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 72148350846.68796
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 72124021587.97287
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 72124021587.97287
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 79847162482.9234
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 74760871809.15408
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 73447043646.68677
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 73122827747.43872
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 72903399206.64748
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 72688254158.93427
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 72415606429.1792
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 72347933135.09076
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 72342231964.37271
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 72342231964.37271
# center shift 0.000000e+00 within tolerance 8.188917e+03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 90474052030.36562
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 90001122793.14375
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 89544572292.11725
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 88176214872.93628
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 85933460316.80554
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 82456623694.53865
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 79960905254.77692
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 78387690380.59178
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 77700878585.41539
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 77177663114.31212
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 76650270674.5641
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 75109548562.47644
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 74370960588.72258
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 73581805371.85147
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 73324402433.66725
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 73191112413.54193
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 73093685709.6383
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 73088205536.83505
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 73079984048.4876
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 73070497744.01451
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 73070497744.01451
# center shift 0.000000e+00 within tolerance 8.188917e+03
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=5, tol=0.0001, verbose=True)

# %%
# write code to analyse the cluster centers
model.cluster_centers_
# Out:
# array([[ 8234.99093656,  3824.33836858,  5322.42296073,  2568.73716012],
#        [ 8119.69387755, 18812.93877551, 27745.36734694,  2011.42857143],
#        [35941.4       ,  6044.45      ,  6288.61666667,  6713.96666667]])

# %%
df3['cluster']=model.predict(df3)
df3.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Fresh   Milk  Grocery  Frozen  cluster
# 0  12669   9656     7561     214        0
# 1   7057   9810     9568    1762        0
# 2   6353   8808     7684    2405        0
# 3  13265   1196     4221    6404        0
# 4  22615   5410     7198    3915        2
# 5   9413   8259     5126     666        0
# 6  12126   3199     6975     480        0
# 7   7579   4956     9426    1669        0
# 8   5963   3648     6192     425        0
# 9   6006  11093    18881    1159        1

# %%
# write code to draw the countplot of the cluster feature from the dataframe df3 and analyze the cluster size
plt.figure(figsize=(8,6))
sns.countplot(model.labels_)
plt.show()

# %% [markdown]
# put comments about the observation

# %%
#Check for best values of k
k = []
cost = []
for i in range(1,15):
  k.append(i)
  model = KMeans(n_clusters=i, random_state = 5)
  model.fit(df2)
  cost.append(model.inertia_)

#plot between cost v/s k
plt.figure(figsize=(12,5))
plt.plot(k,cost)
plt.grid(True)
plt.show()

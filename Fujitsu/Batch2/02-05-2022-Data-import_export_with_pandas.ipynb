# %% [markdown]
# # Data import / Export with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\AI\data\datasets-1\datawh.csv",encoding='latin-1')
df.shape
# Out:
# (20, 5)

# %%
df.head()
# Out:
#         Dates  Temperature  Humidity  Pressure  Air Quality
# 0  30-04-2018          218       182         4            2
# 1  01-05-2018         2592       182         3            2
# 2  02-05-2018          509       439         4            0
# 3  03-05-2018         2439        53         5            1
# 4  04-05-2018          824       444         5            0

# %%
# load data from excel file
df = pd.read_excel(r"D:\AI\data\datasets-1\Wholesale customers data.xlsx")
df.shape
# Out:
# (440, 8)

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
# load data from a json file
df = pd.read_json(r"D:\AI\data\datasets-1\server-metrics.json")
df.shape
# Out:
# (20, 6)

# %%
df.head()
# Out:
#    id          dates  Accepted  Rejected    App     Server
# 0   0  1525046400000       218       182  App_4  Server_02
# 1   1  1525132800000      2592       182  App_3  Server_02
# 2   2  1525219200000       509       439  App_4   Server_0
# 3   3  1525305600000      2439        53  App_5  Server_01
# 4   4  1525392000000       824       444  App_5   Server_0

# %%
url = "https://raw.githubusercontent.com/anshupandey/Machine_Learning_Training/master/datasets/IPL_summary.csv"
df = pd.read_csv(url)
df.shape
# Out:
# (577, 18)

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                   tosswinner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  winbyruns  win_by_wickets  \
# 0  normal           0        Kolkata Knight Riders        140               0
# 1  normal           0          Chennai Super Kings         33               0
# 2  normal           0             Delhi Daredevils          0               9
# 3  normal           0  Royal Challengers Bangalore          0               5
# 4  normal           0        Kolkata Knight Riders          0               5
#
#   player of the match                                       venue    empire1  \
# 0         BB McCullum                       M Chinnaswamy Stadium  Asad Rauf
# 1          MEK Hussey  Punjab Cricket Association Stadium, Mohali  MR Benson
# 2         MF Maharoof                            Feroz Shah Kotla  Aleem Dar
# 3          MV Boucher                            Wankhede Stadium   SJ Davis
# 4           DJ Hussey                                Eden Gardens  BF Bowden
#
#           empire2  empire 3
# 0     RE Koertzen       NaN
# 1      SL Shastri       NaN
# 2  GA Pratapkumar       NaN
# 3       DJ Harper       NaN
# 4     K Hariharan       NaN

# %%
# load data from an xml file
df = pd.read_xml(r"D:\AI\data\datasets-1\books.xml")
df.shape
# Out:
# (12, 7)

# %%
df.head()
# Out:
#       id                author                  title     genre  price  \
# 0  bk101  Gambardella, Matthew  XML Developer's Guide  Computer  44.95
# 1  bk102            Ralls, Kim          Midnight Rain   Fantasy   5.95
# 2  bk103           Corets, Eva        Maeve Ascendant   Fantasy   5.95
# 3  bk104           Corets, Eva        Oberon's Legacy   Fantasy   5.95
# 4  bk105           Corets, Eva     The Sundered Grail   Fantasy   5.95
#
#   publish_date                                        description
# 0   2000-10-01  An in-depth look at creating applications \n  ...
# 1   2000-12-16  A former architect battles corporate zombies, ...
# 2   2000-11-17  After the collapse of a nanotechnology \n     ...
# 3   2001-03-10  In post-apocalypse England, the mysterious \n ...
# 4   2001-09-10  The two daughters of Maeve, half-sisters, \n  ...

# %%
x = "Hello \new world"
print(x)
# Out:
# Hello
# ew world

# %%
x = r"Hello \new world" # raw string
print(x)
# Out:
# Hello \new world

# %%
x = "Hello \\new world"
print(x)
# Out:
# Hello \new world

# %%
pd.read_csv?

# %%
pd.__version__
# Out:
# '1.3.4'

# %% [markdown]
# ### Loading data from html

# %%
url = "https://en.wikipedia.org/wiki/Indian_Premier_League"
dflist = pd.read_html(url)
type(dflist)
# Out:
# list

# %%
len(dflist)
# Out:
# 44

# %%
dflist[0]
# Out:
#                              0  \
# 0         Official Logo of IPL
# 1                    Countries
# 2                Administrator
# 3                       Format
# 4                First edition
# 5               Latest edition
# 6            Tournament format
# 7              Number of teams
# 8             Current champion
# 9              Most successful
# 10                   Most runs
# 11                Most wickets
# 12                          TV
# 13  2022 Indian Premier League
# 14                     Website
#
#                                                     1
# 0                                Official Logo of IPL
# 1                                               India
# 2               Board of Control for Cricket in India
# 3                                            Twenty20
# 4                                                2008
# 5                                                2022
# 6   Round Robin format with Group System and Playoffs
# 7                                                  10
# 8                     Chennai Super Kings (4th title)
# 9                           Mumbai Indians (5 titles)
# 10                                 Virat Kohli (6284)
# 11                                 Dwayne Bravo (181)
# 12                               List of broadcasters
# 13                         2022 Indian Premier League
# 14                                         iplt20.com

# %%
dflist[1]
# Out:
#                                              Seasons  \
# 0  2008 2009 2010 2011 2012 2013 2014 2015 2016 2...
#
#                                            Seasons.1
# 0  2008 2009 2010 2011 2012 2013 2014 2015 2016 2...

# %%
dflist[2]
# Out:
#    Team                       Team.1                    City  \
# 0   NaN          Chennai Super Kings     Chennai, Tamil Nadu
# 1   NaN               Delhi Capitals        New Delhi, Delhi
# 2   NaN               Gujarat Titans      Ahmedabad, Gujarat
# 3   NaN        Kolkata Knight Riders    Kolkata, West Bengal
# 4   NaN         Lucknow Super Giants  Lucknow, Uttar Pradesh
# 5   NaN               Mumbai Indians     Mumbai, Maharashtra
# 6   NaN                 Punjab Kings          Mohali, Punjab
# 7   NaN             Rajasthan Royals       Jaipur, Rajasthan
# 8   NaN  Royal Challengers Bangalore    Bangalore, Karnataka
# 9   NaN          Sunrisers Hyderabad    Hyderabad, Telangana
#
#                                   Home ground  Debut  \
# 0                   M. A. Chidambaram Stadium   2008
# 1                        Arun Jaitley Stadium   2008
# 2                       Narendra Modi Stadium   2022
# 3                                Eden Gardens   2008
# 4                BRSABV Ekana Cricket Stadium   2022
# 5                            Wankhede Stadium   2008
# 6               Inderjit Singh Bindra Stadium   2008
# 7                      Sawai Mansingh Stadium   2008
# 8                      M. Chinnaswamy Stadium   2008
# 9  Rajiv Gandhi International Cricket Stadium   2013
#
#                                              Owner          Captain  \
# 0                                    N. Srinivasan      M. S. Dhoni
# 1                          Sajjan Jindal G. M. Rao     Rishabh Pant
# 2  Steve Koltes Donald Mackenzie Rolly van Rappard    Hardik Pandya
# 3             Shah Rukh Khan Juhi Chawla Jay Mehta     Shreyas Iyer
# 4                                    Sanjiv Goenka         KL Rahul
# 5                                    Mukesh Ambani     Rohit Sharma
# 6  Mohit Burman Ness Wadia Preity Zinta Karan Paul   Mayank Agarwal
# 7     Manoj Badale Lachlan Murdoch Gerry Cardinale     Sanju Samson
# 8                                 Prathmesh Mishra   Faf du Plessis
# 9                                  Kalanithi Maran  Kane Williamson
#
#            Head Coach
# 0     Stephen Fleming
# 1       Ricky Ponting
# 2        Ashish Nehra
# 3    Brendon McCullum
# 4         Andy Flower
# 5  Mahela Jayawardene
# 6         Anil Kumble
# 7     Kumar Sangakara
# 8       Sanjay Bangar
# 9           Tom Moody

# %%
dflist[3]
# Out:
#    Team                  Team.1                  City  \
# 0   NaN         Deccan Chargers  Hyderabad, Telangana
# 1   NaN    Kochi Tuskers Kerala         Kochi, Kerala
# 2   NaN     Pune Warriors India     Pune, Maharashtra
# 3   NaN           Gujarat Lions       Rajkot, Gujarat
# 4   NaN  Rising Pune Supergiant     Pune, Maharashtra
#
#                                   Home ground  Debut  Dissolved  \
# 0  Rajiv Gandhi International Cricket Stadium   2008       2012
# 1                    Jawaharlal Nehru Stadium   2011       2011
# 2     Maharashtra Cricket Association Stadium   2011       2013
# 3      Saurashtra Cricket Association Stadium   2016       2018
# 4     Maharashtra Cricket Association Stadium   2016       2018
#
#                                Owner
# 0  T. Venkattram Reddy Gayatri Reddy
# 1              Kochi Cricket Pvt Ltd
# 2                        Subrata Roy
# 3                      Keshav Bansal
# 4                      Sanjiv Goenka

# %%
dflist[4]
# Out:
#    Team                       Team.1 Title(s) Runner-upground  \
# 0   NaN               Mumbai Indians        5               1
# 1   NaN          Chennai Super Kings        4               5
# 2   NaN        Kolkata Knight Riders        2               1
# 3   NaN             Rajasthan Royals        1               –
# 4   NaN             Deccan Chargers†        1               –
# 5   NaN          Sunrisers Hyderabad        1               1
# 6   NaN  Royal Challengers Bangalore        –               3
# 7   NaN               Delhi Capitals        –               1
# 8   NaN      Rising Pune Supergiant†        –               1
# 9   NaN                 Punjab Kings        –               1
#
#             Seasons won     Seasons runner-up  No. of seasons played
# 0  20132015201720192020                  2010                     14
# 1      2010201120182021  20082012201320152019                     12
# 2              20122014                  2021                     14
# 3                  2008                     –                     12
# 4                  2009                     –                      5
# 5                  2016                  2018                      9
# 6                     –          200920112016                     14
# 7                     –                  2020                     14
# 8                     –                  2017                      2
# 9                     –                  2014                     14

# %%
dflist[5]
# Out:
#          Season  Final                                               \
#          Season Winner                                     Winner.1
# 0   2008Details    NaN         Rajasthan Royals[49]164/7 (20 overs)
# 1   2009Details    NaN          Deccan Chargers[51]143/6 (20 overs)
# 2   2010Details    NaN      Chennai Super Kings[53]168/5 (20 overs)
# 3   2011Details    NaN      Chennai Super Kings[55]205/5 (20 overs)
# 4   2012Details    NaN  Kolkata Knight Riders[57]192/5 (19.4 overs)
# 5   2013Details    NaN           Mumbai Indians[59]148/9 (20 overs)
# 6   2014Details    NaN  Kolkata Knight Riders[61]200/7 (19.3 overs)
# 7   2015Details    NaN           Mumbai Indians[63]202/5 (20 overs)
# 8   2016Details    NaN      Sunrisers Hyderabad[65]208/7 (20 overs)
# 9   2017Details    NaN           Mumbai Indians[67]129/8 (20 overs)
# 10  2018Details    NaN    Chennai Super Kings[69]181/2 (18.3 overs)
# 11  2019Details    NaN           Mumbai Indians[71]149/8 (20 overs)
# 12  2020Details    NaN         Mumbai Indians[73]157/5 (18.4 overs)
# 13  2021Details    NaN      Chennai Super Kings[75]192/3 (20 overs)
# 14  2022Details    NaN                                          NaN
#
#                                            \
#                  Winning margin Runner-up
# 0   Won by 3 wickets(Scorecard)       NaN
# 1      Won by 6 runs(Scorecard)       NaN
# 2     Won by 22 runs(Scorecard)       NaN
# 3     Won by 58 runs(Scorecard)       NaN
# 4   Won by 5 wickets(Scorecard)       NaN
# 5     Won by 23 runs(Scorecard)       NaN
# 6   Won by 3 wickets(Scorecard)       NaN
# 7     Won by 41 runs(Scorecard)       NaN
# 8      Won by 8 runs(Scorecard)       NaN
# 9       Won by 1 run(Scorecard)       NaN
# 10  Won by 8 wickets(Scorecard)       NaN
# 11      Won by 1 run(Scorecard)       NaN
# 12  Won by 5 wickets(Scorecard)       NaN
# 13    Won by 27 runs(Scorecard)       NaN
# 14                          NaN       NaN
#
#                                                      \
#                                         Runner-up.1
# 0           Chennai Super Kings[49]163/5 (20 overs)
# 1   Royal Challengers Bangalore[51]137/9 (20 overs)
# 2                Mumbai Indians[53]146/9 (20 overs)
# 3   Royal Challengers Bangalore[55]147/8 (20 overs)
# 4           Chennai Super Kings[57]190/3 (20 overs)
# 5           Chennai Super Kings[59]125/9 (20 overs)
# 6               Kings XI Punjab[61]199/4 (20 overs)
# 7           Chennai Super Kings[63]161/8 (20 overs)
# 8   Royal Challengers Bangalore[65]200/7 (20 overs)
# 9        Rising Pune Supergiant[67]128/6 (20 overs)
# 10          Sunrisers Hyderabad178/6 (20 overs)[69]
# 11          Chennai Super Kings[71]148/7 (20 overs)
# 12               Delhi Capitals[73]156/7 (20 overs)
# 13        Kolkata Knight Riders[75]165/9 (20 overs)
# 14                                              NaN
#
#                                           Final venue No. ofteams  \
#                                           Final venue No. ofteams
# 0                   DY Patil Stadium, Navi Mumbai[49]       8[50]
# 1                 Wanderers Stadium, Johannesburg[51]       8[52]
# 2                   DY Patil Stadium, Navi Mumbai[53]       8[54]
# 3              M. A. Chidambaram Stadium, Chennai[55]      10[56]
# 4              M. A. Chidambaram Stadium, Chennai[57]       9[58]
# 5                           Eden Gardens, Kolkata[59]       9[60]
# 6               M. Chinnaswamy Stadium, Bengaluru[61]       8[62]
# 7                           Eden Gardens, Kolkata[63]       8[64]
# 8               M. Chinnaswamy Stadium, Bengaluru[65]       8[66]
# 9   Rajiv Gandhi International Cricket Stadium, Hy...       8[68]
# 10                       Wankhede Stadium, Mumbai[69]       8[70]
# 11  Rajiv Gandhi International Cricket Stadium, Hy...       8[72]
# 12     Dubai International Cricket Stadium, Dubai[73]       8[74]
# 13     Dubai International Cricket Stadium, Dubai[75]       8[76]
# 14                                                NaN         NaN
#
#     Player of the series
#     Player of the series
# 0       Shane Watson(RR)
# 1     Adam Gilchrist(DC)
# 2   Sachin Tendulkar(MI)
# 3       Chris Gayle(RCB)
# 4      Sunil Narine(KKR)
# 5       Shane Watson(RR)
# 6    Glenn Maxwell(KXIP)
# 7     Andre Russell(KKR)
# 8       Virat Kohli(RCB)
# 9       Ben Stokes(RPSG)
# 10     Sunil Narine(KKR)
# 11    Andre Russell(KKR)
# 12      Jofra Archer(RR)
# 13    Harshal Patel(RCB)
# 14                   NaN
